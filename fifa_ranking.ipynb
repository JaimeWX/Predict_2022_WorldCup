# %%
import pandas as pd

# %%
rank = pd.read_csv("/wx/Predicting_2022_WorldCop/data/fifa_ranking-2022-10-06.csv")
rank.shape[0]
# Out:
# 63916

# %%
rank.tail()
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 63911    74  El Salvador          SLV       1330.51          1333.48
# 63912    75         Oman          OMA       1320.29          1323.03
# 63913    76       Israel          ISR       1316.55          1316.35
# 63914    78      Georgia          GEO       1307.34          1296.46
# 63915   211   San Marino          SMR        762.22           763.82
#
#        rank_change confederation   rank_date
# 63911            3      CONCACAF  2022-10-06
# 63912            0           AFC  2022-10-06
# 63913            0          UEFA  2022-10-06
# 63914           -4          UEFA  2022-10-06
# 63915            0          UEFA  2022-10-06

# %%
rank_2022 = rank[(rank['rank_date'] >= "2022-01-01")]
rank_2022.head()
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 62862    76      Bolivia          BOL       1308.12          1324.21
# 62863    70  El Salvador          SLV       1346.04          1349.47
# 62864    71     Bulgaria          BUL       1345.47          1345.47
# 62865    73   Cabo Verde          CPV       1336.88          1339.48
# 62866    74         Iraq          IRQ       1325.44          1333.03
#
#        rank_change confederation   rank_date
# 62862           -1      CONMEBOL  2022-02-10
# 62863            0      CONCACAF  2022-02-10
# 62864            0          UEFA  2022-02-10
# 62865            0           CAF  2022-02-10
# 62866           -1           AFC  2022-02-10

# %%
rank_2022['rank_date'].value_counts()
# Out:
# 2022-10-06    211
# 2022-08-25    211
# 2022-06-23    211
# 2022-03-31    211
# 2022-02-10    210
# Name: rank_date, dtype: int64

# %%
rank_2022 = rank_2022[(rank_2022['rank_date'] >= "2022-10-01")]
rank_2022.head()
# Out:
#        rank         country_full country_abrv  total_points  previous_points  \
# 63705   142            Nicaragua          NCA       1071.83          1079.18
# 63706   141              Burundi          BDI       1076.26          1076.26
# 63707   140  St. Kitts and Nevis          SKN       1076.91          1076.91
# 63708   135         Turkmenistan          TKM       1100.47          1100.47
# 63709   138             Ethiopia          ETH       1091.19          1088.27
#
#        rank_change confederation   rank_date
# 63705            3      CONCACAF  2022-10-06
# 63706            0           CAF  2022-10-06
# 63707            0      CONCACAF  2022-10-06
# 63708            0           AFC  2022-10-06
# 63709            0           CAF  2022-10-06

# %%
rank_2022 = rank_2022.sort_values('total_points',ascending=False)
rank_2022.head()
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 63809     1       Brazil          BRA       1841.30          1837.56
# 63838     2      Belgium          BEL       1816.71          1821.92
# 63839     3    Argentina          ARG       1773.88          1770.65
# 63840     4       France          FRA       1759.78          1764.85
# 63841     5      England          ENG       1728.47          1737.46
#
#        rank_change confederation   rank_date
# 63809            0      CONMEBOL  2022-10-06
# 63838            0          UEFA  2022-10-06
# 63839            0      CONMEBOL  2022-10-06
# 63840            0          UEFA  2022-10-06
# 63841            0          UEFA  2022-10-06

# %%
print(rank_2022[rank_2022['country_full'].isin(['China PR'])])
# Out:
#        rank country_full country_abrv  total_points  previous_points  \
# 63889    79     China PR          CHN       1305.06          1305.06
#
#        rank_change confederation   rank_date
# 63889            1           AFC  2022-10-06

# %%
rank_2022_AFC = rank_2022[rank_2022['confederation'] == 'AFC']
rank_2022_AFC.shape[0]
# Out:
# 46

# %%
rank_2022_AFC.head(46)
# Out:
#        rank          country_full country_abrv  total_points  previous_points  \
# 63856    20               IR Iran          IRN       1564.61          1558.64
# 63836    24                 Japan          JPN       1559.54          1554.69
# 63811    28        Korea Republic          KOR       1530.30          1526.02
# 63822    38             Australia          AUS       1488.72          1483.73
# 63860    50                 Qatar          QAT       1439.89          1441.97
# 63861    51          Saudi Arabia          KSA       1437.78          1435.74
# 63905    68                  Iraq          IRQ       1343.01          1338.91
# 63907    70  United Arab Emirates          UAE       1337.57          1346.09
# 63912    75                  Oman          OMA       1320.29          1323.03
# 63890    77            Uzbekistan          UZB       1309.98          1306.63
# 63889    79              China PR          CHN       1305.06          1305.06
# ...

# %%
rank_2022["country_full"] = rank_2022["country_full"].str.replace("IR Iran", "Iran").str.replace("Korea Republic", "South Korea").str.replace("USA", "United States")
